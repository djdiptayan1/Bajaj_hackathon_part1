# %%
import requests
from bs4 import BeautifulSoup as bs
import json
from textblob import TextBlob

# %%
url = 'https://bajajfinserv.in/finance/personal-loan'
base_url = 'https://bajajfinserv.in'

# %%
def get_valid_url(url, base_url):
    if url.startswith('http'):
        return url
    elif url.startswith('/'):
        return f"{base_url}{url}"
    else:
        return f"{base_url}/{url}"

# %%
response = requests.get(url)
# response = requests.get(base_url)
print(response.status_code)

html_content = response.content
soup = bs(html_content, 'html.parser')
# Out:
# 404

# %%
# Step 1: Extract the URLs of the pages you want to visit
page_urls = [get_valid_url(link.get('href'), base_url) for link in soup.find_all('a') if link.get('href')]
print(page_urls)
# Out:
# ['https://bajajfinserv.in/personal-loan', 'https://bajajfinserv.in/business-loan', 'https://bajajfinserv.in/home-loan', 'https://bajajfinserv.in/gold-loan', 'https://bajajfinserv.in/rbl-dbs-credit-cards?cardType=CC_RBL', 'https://bajajfinserv.in/rbl-dbs-credit-cards?cardType=CC_DBS', 'https://bajajfinserv.in/insta-emi-card', 'https://bajajfinserv.in/marketplace/pocketInsurance/?product=WalletCare&product_code=WPCP', 'https://bajajfinserv.in/marketplace/insurance/health-insurance/health-insurance-premium-calculator/getGoingNow', 'https://bajajfinserv.in/doctor-loan', 'https://bajajfinserv.in/investments/fixed-deposit', 'https://bajajfinserv.in/loan-against-property', 'https://bajajfinserv.in/chartered-accountant-loan', 'https://bajajfinserv.in/demat-account', 'https://bajajfinserv.in/two-wheeler-loan/application-form?utm_source=bfl_website&utm_medium=referral&utm_campaign=mkt_bfl_footer_240622_two_wheeler&utm_content=bfl_footer', 'https://bajajfinserv.in/new-car-finance', 'https://bajajfinserv.in/used-car-finance', 'https://bajajfinserv.in/loan-against-car', 'https://bajajfinserv.in/car-loan-balance-transfer-and-top-up', 'https://bajajfinserv.in/personal-loan', 'https://bajajfinserv.in/insta-personal-loan', 'https://bajajfinserv.in/business-loan', 'https://bajajfinserv.in/home-loan', 'https://bajajfinserv.in/gold-loan', 'https://bajajfinserv.in/msme-world', 'https://bajajfinserv.in/mortgage-loan', 'https://bajajfinserv.in/loan-against-property', 'https://bajajfinserv.in/two-wheeler-loan', 'https://bajajfinserv.in/education-loan-on-property', 'https://bajajfinserv.in/personal-loan-for-self-employed', 'https://bajajfinserv.in/two-wheeler-loan', 'https://bajajfinserv.in/new-car-finance', 'https://bajajfinserv.in/used-car-finance', 'https://bajajfinserv.in/loan-against-car', 'https://bajajfinserv.in/car-loan-balance-transfer-and-top-up', 'https://bajajfinserv.in/insurance/health-insurance-all-products', 'https://bajajfinserv.in/insurance/car-insurance-all-products', 'https://bajajfinserv.in/insurance/two-wheeler-insurance-all-products', 'https://bajajfinserv.in/insurance/pocket-insurance-all-products', 'https://bajajfinserv.in/insurance/investment-plans-all-products', 'https://bajajfinserv.in/insurance/appliances-extended-warranty-all-products', 'https://bajajfinserv.in/insurance/pocket-subscription-all-products', 'https://bajajfinserv.in/doctor-loan', 'https://bajajfinserv.in/chartered-accountant-loan', 'https://bajajfinserv.in/investments/fixed-deposit', 'https://bajajfinserv.in/investments/systematic-deposit-plan', 'https://bajajfinserv.in/demat-account', 'https://bajajfinserv.in/investments/mutual-funds', 'https://bajajfinserv.in/insurance/mobile-screen-insurance', 'https://bajajfinserv.in/insurance/wallet-care', 'https://bajajfinserv.in/insurance/fonesafe-lite', 'https://bajajfinserv.in/insurance/cycle-secure', 'https://bajajfinserv.in/insurance/health-prime-max', 'https://bajajfinserv.in/insurance/watch-secure', 'https://bajajfinserv.in/insurance/key-safeguard', 'https://www.bajajmall.in/emi-store/smartphones.html?utm_source=bfl_website&utm_medium=referral&utm_campaign=mktplc_footer_05122020_DPF_Generic&utm_content=footer&store_ga=665472662.1639983038', 'https://www.bajajmall.in/emi-store/mattress.html?utm_source=bfl_website&utm_medium=referral&utm_campaign=mktplc_footer_21022022_LSF_Generic&utm_content=footer&store_ga=665472662.1639983038', 'https://www.bajajmall.in/emi-store/smart-watches.html?utm_source=bfl_website&utm_medium=referral&utm_campaign=mktplc_footer_21022022_REMI_Generic&utm_content=footer&store_ga=665472662.1639983038', 'https://www.bajajmall.in/emi-store/cycles.html?utm_source=bfl_website&utm_medium=referral&utm_campaign=mktplc_footer_21022022_REMI_Generic&utm_content=footer&store_ga=665472662.1639983038', 'https://www.bajajmall.in/emi-store/music-and-audio-system.html?utm_source=bfl_website&utm_medium=referral&utm_campaign=mktplc_footer_21022022_REMI_Generic&utm_content=footer&store', 'https://www.bajajmall. ...

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4464.5 Safari/537.36'}
response = requests.get(url, headers=headers).text

# %%
soup = bs(response, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    404
#   </title>
#   <link href="https://www.bajajfinserv.in/404" rel="canonical"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <meta content="custom" name="tagorigin"/>
#   <meta content="home-page" name="template"/>
#   <meta content="no" name="vernac"/>
#   <meta content="404" property="og:title"/>
#   <meta content="www.bajajfinserv.in" property="og:site_name"/>
#   <meta content="/content/dam/bajajfinserv/web/in/en/global/image/logo/OG-thumbnail.png" property="og:image"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, minimal-ui" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);if (w.matchMedia('(display-mode: standalone)').matches){  w[l].push({ event:"pwa_gtm_init","platform_source":"pwa"});}})(window,document,'script','dataLayer','GTM-M8JQCJL');
#   </script>
#   <script type="text/javascript">
#    ;window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true},privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]}};
#
#         ;NREUM.loader_config={accountID:"2364187",trustKey:"2442591",agentID:"1120217654",licenseKey:"a26b546289",applicationID:"1120217654"};
#         ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"a26b546289",applicationID:"1120217654",sa:1};
#         ;/*! For license information please see nr-loader-spa-1.237.1.min.js.LICENSE.txt */
#         (()=>{"use strict";var e,t,r={5763:(e,t,r)=>{r.d(t,{P_:()=>f,Mt:()=>g,C5:()=>s,DL:()=>v,OP:()=>T,lF:()=>j,Yu:()=>y,Dg:()=>h,CX:()=>c,GE:()=>b,sU:()=>_});var n=r(8632),i=r(9567);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o),(0,n.Qy)(e,a[e],"info")}var d=r(7056);const u=()=>{const e={blockSelector:"[data-nr-block]",maskInputOptions:{password:!0}};return{allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1},session_trace:{enabled:!0,harvestTimeSeconds:10},harvest:{tooManyRequestsDelay:60},session_replay:{enabled:!1,harvestTimeSeconds:60,sampleRate:.1,errorSampleRate:.1,maskTextSelector:"*",maskAllInputs:!0,get blockClass(){return"nr-block"},get ignoreClass(){return"nr-ignore"},get maskTextClass(){return"nr-mask"},get blockSelector(){return e.blockSelector},set blockSelector(t){e.blockSelector+=",".concat(t)},get maskInputOptions(){return e.maskInputOptions},set maskInputOptions(t){e.maskInputOptions={...t,password:!0}}},spa:{enabled:!0,harvestTimeSeconds:10}}},l={};function f(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!l[e])throw new Error("Configuration for ".concat(e," was never set"));return l[e]}function h(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");l[e]=(0,i.D)(t,u()),(0,n.Qy)(e,l[e],"config")}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var r=f(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const p={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},m={};function v(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!m[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return m[e]}function b(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");m[e]=(0,i.D)(t,p),(0,n.Qy)(e,m[e],"loader_config")}const y=(0,n.mF)().o;var w=r(385),x=r(6818);const A={buildEnv:x.Re,bytesSent:{},queryBytesSent:{},customTransaction:void 0,disabled:!1,distMethod:x.gF,isolatedBacklog:!1,loaderType:void 0,maxBytes:3e4,offset:Math.floor(w._A?.performance?.timeOrigin||w._A?.performance?.timing?.navigationStart||Date.now()),onerror:void 0,origin:""+w._A.location,ptid:void 0,releaseIds:{},session:void 0,xhrWrappable:"function"==typeof w._A.XMLHttpRequest?.prototype?.addEventListener,version:x.q4,denyList:void 0},E={};function T(e){if(!e)throw new Error("All runtime objects require an agent identifier!");if(!E[e])throw new Error("Runtime for ".concat(e," was never set"));return E[e]}function _(e,t){if(!e)throw new Error("All runtime objects require an agent identifier!");E[e]=(0,i.D)(t,A),(0,n.Qy)(e,E[e],"runtime")}function j(e){return function(e){try{const t=s(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID}catch(e){return!1}}(e)}},9567:(e,t,r)=>{r.d(t,{D:()=>i});var n=r(50); ...
#   </script>
#   <script>
#    // start utm script
#   var campaignUtmSource = 'organic_bfl';
#   if (window.location.href.toString().includes('/service-guides')) {
#     campaignUtmSource = 'organic_myaccount';
#   }
# 	function getUrlValue(name) {
# 		name = name.replace(/[\[]/, "\\[").replace(/[\]]/, "\\]");
#         var regex = new RegExp("[\\?&]" + name + "=([^&#]*)"),
#         results = regex.exec(location.search);
#         return results === null ? "" : decodeURIComponent(results[1].replace(/\+/g, " "));
# 	}
#
# 	function GetCookie(cname) {
# 		var name = cname + "=";
# 		var decodedCookie = decodeURIComponent(document.cookie);
# 		var ca = decodedCookie.split(';');
# 		for (var i = 0; i < ca.length; i++) {
# 			var c = ca[i];
# 			while (c.charAt(0) == ' ') {
# 				c = c.substring(1);
# 			}
# 			if (c.indexOf(name) == 0) {
# 				return c.substring(name.length, c.length);
# 			}
# 		}
# 		return "";
# 	}
#
# 	function getDomain() {
# 		const hostname = window.location.hostname.split('.');
# 		hostname.reverse();
# 		return '.'+`${hostname[1]}.${hostname[0]}`;
# 	}
#
# 	var utm_source = 'null';
# 	var utm_medium = 'null';
# 	var utm_keyword = 'null';
# 	var utm_campaign = 'null';
# 	var utm_content = 'null';
#         var domain=getDomain();
#         var d = new Date(); d.setTime(d.getTime() + (24 * 60 * 60 * 1000));
#         var tvc_expires = d.toUTCString();
# 	if (document.referrer === undefined || document.referrer === null)
# 	{
# 		referrer = 'NA';
# 		//console.log("Unknown");
# 	} else if (document.referrer.split('/')[2] === window.location.hostname) {
# 		referrer = 'samedomain';
# 		// console.log(document.referrer.split('/')[2]);
# 	} else {
# 		referrer = document.referrer;
# 		// console.log(referrer);
# 	}
# 	var campaignCookie = GetCookie('campaignCookie');
# 	if (campaignCookie)
# 	{
# 		campaignCookie = JSON.parse(campaignCookie);
# 		var campaign = {};
# 		utm_source = getUrlValue('utm_source');
# 		if (!utm_source) {
# 			utm_source = 'null';
# 		}
# 		utm_medium = getUrlValue('utm_medium');
# 		if (!utm_medium) {
# 			utm_medium = 'null';
# 		}
# 		utm_campaign = getUrlValue('utm_campaign');
# 		if (!utm_campaign) {
# 			utm_campaign = 'null';
# 		}
# 		utm_content = getUrlValue('utm_content');
# 		if (!utm_content) {
# 			utm_content = 'null';
# 		}
# 		utm_keyword = getUrlValue('utm_keyword');
# 		if (!utm_keyword) {
# 			utm_keyword = 'null';
# 		}
# 		if (referrer == 'NA')
# 		{
# 			campaign.utm_medium = 'bfl';
# 			campaign.utm_campaign = 'NA';
# 			campaign.utm_keyword = 'NA';
# 			campaign.utm_source = campaignUtmSource;
# 		} else if (referrer == 'samedomain')
# 		{
# 			// console.log("--- Same Domain -----");
# 			if (utm_medium != null || utm_campaign != null || utm_keyword != null || utm_source != null || utm_content != null)
# 			{
# 				if (utm_medium === 'null' || utm_medium === null)
# 				{
# 					if (campaignCookie.utm_medium != 'bfl')
# 					{
# 						campaign.utm_medium = campaignCookie.utm_medium;
# 					} else {
# 						campaign.utm_medium = 'bfl';
# 					}
# 				} else {
# 					campaign.utm_medium = utm_medium;
# 				}
# 				if (utm_campaign === 'null' || utm_campaign === null) {
# 					if (campaignCookie.utm_campaign != 'NA')
# 					{
# 						campaign.utm_campaign = campaignCookie.utm_campaign;
# 					} else {
# 						campaign.utm_campaign = 'NA';
# 					}
# 				} else {
# 					campaign.utm_campaign = utm_campaign;
# 				}
# 				if (utm_keyword === 'null' || utm_keyword === null) {
# 					if (campaignCookie.utm_keyword != 'NA')
# 					{
# 						campaign.utm_keyword = campaignCookie.utm_keyword;
# 					} else {
# 						campaign.utm_keyword = 'NA';
# 					}
# 				} else {
# 					campaign.utm_keyword = utm_keyword;
# 				}
# 				if (utm_source === 'null' || utm_source === null) {
# 					if (campaignCookie.utm_source != campaignUtmSource)
# 					{
# 						campaign.utm_source = campaignCookie.utm_source;
# 					} else {
# 						campaign.utm_source = campaignUtmSource;
# 					}
# 				} else {
# 					campaign.utm_source = utm_source;
# 				}
# 				if (utm_content === 'null' || utm_content === null) {
# 					if (campaignCookie.utm_content != 'NA')
# 					{
# 						campaign.utm_content = campaignCookie.utm_content;
# 					} else {
# 						campaign.utm_content = 'NA';
# 					}
# 				} else {
# 					campaign.utm_content = utm_content;
# 				}
# 			}
# 		} else {
# 			//    console.log("--- Campaign Page  -----");
# 			if (utm_medium != null || utm_campaign != null || utm_keyword != null || utm_source != null || utm_content != null)
# 			{
# 				if (utm_medium === 'null' || utm_medium === null) {
# 					if (campaignCookie.utm_medium != 'bfl')
# 					{
# 						campaign.utm_medium = campaignCookie.utm_medium;
# 					} else {
# 						campaign.utm_medium = 'bfl';
# 					}
# 				} else {
# 					campaign.utm_medium = utm_medium;
# 				}
# 				if (utm_campaign === 'null' || utm_campaign === null) {
# 					if (campaignCookie.utm_campaign != 'NA')
# 					{
# 						campaign.utm_campaign = campaignCookie.utm_campaign;
# 					} else {
# 						campaign.utm_campaign = 'NA';
# 					}
# 				} else {
# 					campaign.utm_campaign = utm_campaign;
# 				}
# 				if (utm_keyword === 'null' || utm_keyword === null) {
# 					if (campaignCookie.utm_keyword != 'NA')
# 					{
# 						campaign.utm_keyword = campaignCookie.utm_keyword;
# 					} else
# 					{
# 						campaign.utm_keyword = 'NA';
# 					}
# 				} else {
# 					campaign.utm_keyword = utm_keyword;
# 				}
# 				if (utm_source === 'null' || utm_source === null) {
# 					if (campaignCookie.utm_source != campaignUtmSource)
# 					{
# 						campaign.utm_source = campaignCookie.utm_source;
# 					} else {
# 						campaign.utm_source = campaignUtmSource;
# 					}
# 				} else {
# 					campaign.utm_source = utm_source;
# 				}
# 				if (utm_content === 'null' || utm_content === null) {
# 					if (campaignCookie.utm_content != 'NA')
# 					{
# 						campaign.utm_content = campaignCookie.utm_content;
# 					} else {
# 						campaign.utm_content = 'NA';
# 					}
# 				} else {
# 					campaign.utm_content = utm_content;
# 				}
# 			}
# 		}
# 		var date = new Date();
# 		date.setTime(date.getTime() + (30 * 60 * 1000));
# 		document.cookie = "campaignCookie=" + JSON.stringify(campaign) + ";domain="+domain+ "; path=/" + "; secure";
# 		UtmPushToGTM();
# 	} else
# 	{
# 		var date = new Date();
# 		date.setTime(date.getTime() + (30 * 60 * 1000));
# 		var campaign = {};
# 		utm_source = getUrlValue('utm_source');
# 		if (!utm_source) {
# 			utm_source = 'null';
# 		}
# 		utm_medium = getUrlValue('utm_medium');
# 		if (!utm_medium) {
# 			utm_medium = 'null';
# 		}
# 		utm_campaign = getUrlValue('utm_campaign');
# 		if (!utm_campaign) {
# 			utm_campaign = 'null';
# 		}
# 		utm_content = getUrlValue('utm_content');
# 		if (!utm_content) {
# 			utm_content = 'null';
# 		}
# 		utm_keyword = getUrlValue('utm_keyword');
# 		if (!utm_keyword) {
# 			utm_keyword = 'null';
# 		}
# 		if (utm_medium == null || utm_medium === 'null')
# 		{
# 			campaign.utm_medium = 'bfl';
# 		} else {
# 			campaign.utm_medium = utm_medium;
# 		}
# 		if (utm_campaign == null || utm_campaign === 'null')
# 		{
# 			campaign.utm_campaign = 'NA';
# 		} else {
# 			campaign.utm_campaign = utm_campaign;
# 		}
# 		if (utm_keyword == null || utm_keyword === 'null') {
# 			campaign.utm_keyword = 'NA';
# 		} else {
# 			campaign.utm_keyword = utm_keyword;
# 		}
# 		if (utm_source == null || utm_source === 'null') {
# 			campaign.utm_source = campaignUtmSource;
# 		} else {
# 			campaign.utm_source = utm_source;
# 		}
# 		if (utm_content == null || utm_content === 'null') {
# 			campaign.utm_content = 'NA';
# 		} else {
# 			campaign.utm_content = utm_content;
# 		}
# 		document.cookie = "campaignCookie=" + JSON.stringify(campaign) + ";domain="+domain+";  path=/" + "; secure";
# 		UtmPushToGTM();
# 	}
# 	function UtmPushToGTM() {
# 		var utmCookie = GetCookie('campaignCookie');
# 		utmCookie = JSON.parse(utmCookie);
# 	//	console.log("push to UTM " + utmCookie.utm_source + "----" + utmCookie.utm_medium + "----" + utmCookie.utm_campaign + "========" + utmCookie.utm_content + "==" + utmCookie.utm_keyword);
# 		window.dataLayer = window.dataLayer || [];
# 		dataLayer.push({
# 			'event': 'utm_campaign_stamping',
# 			'page_url': document.location.pathname,
# 			'utm_source': utmCookie.utm_source,
# 			'utm_medium': utmCookie.utm_medium,
# 			'utm_campaign': utmCookie.utm_campaign,
# 			'utm_content': utmCookie.utm_content,
# 			'utm_keyword': utmCookie.utm_keyword,
# 		});
# 	}
#   // end Script
#   // 22Apr-2023
#   </script>
#   <link href="/etc.clientlibs/bajajfinserv-web/clientlibs/clientlib-site.min.3769d3aae5b398baa3d102ef9025877f.css" rel="stylesheet" type="text/css"/>
#   <link href="/etc.clientlibs/bajajfinserv-web/clientlibs/clientlib-bfl.min.b2fb516b01f4f0141abd6b57d696f718.css" rel="stylesheet" type="text/css"/>
#   <link href="/etc.clientlibs/bajajfinserv-web/clientlibs/clientlib-base.min.89f44a324b9523602932749328f7ba99.css" rel="stylesheet" type="text/css"/>
#   <link href="/content/dam/bajajfinserv/web/in/en/global/image/logo/baflicon.ico" rel="SHORTCUT ICON" type="image/x-icon">
#   </link>
#  </head>
#  <body data-countrycode="in" data-kpointapiurl="https://videos.bajajfinserv.in/api/v1/xapi" data-kpointvideourl="https://videos.bajajfinserv.in/kapsule/${videoId}/nv3/embedded" data-nodeurl="https://webservices.bajajfinserv.in">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M8JQCJL" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    function createLastClickCookie(){
# var d = new Date(); d.setTime(d.getTime() + (24 * 60 * 60 * 1000));
# domain = location.hostname.replace("www", "");
# var tvc_links = document.querySelectorAll('a,button');
# if (tvc_links.length > 0) {
# for (var i = 0; i < tvc_links.length; i++) {
# if (tvc_links[i].localName == 'a') {
# tvc_links[i].addEventListener('click', function () {
# var tvc_innerText = this.innerText.trim().replace(/\n/g, '-');
# if (tvc_innerText == '') {
# if (this.children[0].alt) {
# tvc_innerText = this.children[0].alt.trim().replace(/\n/g, '-');
# } else if (this.closest('[data-component]').dataset.component) {
# tvc_innerText = this.closest('[data-component]').dataset.component
# } else {
# tvc_innerText = "NA"
# }
# }
# if (this.closest('[data-component]').dataset.component) {
# var component = this.closest('[data-component]').dataset.component
# } else {
# var component = "NA"
# }
# if(component != "OfferLoginModal")
# {
#     var tvc_click_Text = window.location.pathname + " > " + component + " > " + tvc_innerText;
#     var tvc_value = '{"click":"' + tvc_click_Text + '"}';
#     document.cookie = 'LastClickCookie=' + tvc_value + ';domain=' + domain + ';path=/';
# }
# });
# } else if (tvc_links[i].localName == 'button') {
# tvc_links[i].addEventListener('click', function () {
# var tvc_innerText = this.innerText.trim().replace(/\n/g, '-');
# if (tvc_innerText == '') {
# if (this.children[0].alt) {
# tvc_innerText = this.children[0].alt.trim().replace(/\n/g, '-');
# } else if (this.closest('[data-component]').dataset.component) {
# tvc_innerText = this.closest('[data-component]').dataset.component
# } else {
# tvc_innerText = "NA"
# }
# }
# if (this.closest('[data-component]').dataset.component) {
# var component = this.closest('[data-component]').dataset.component
# } else {
# var component = "NA"
# }
# if(component != "OfferLoginModal")
# {
#     var tvc_click_Text = window.location.pathname + " > " + component + " > " + tvc_innerText;
#     var tvc_value = '{"click":"' + tvc_click_Text + '"}';
#     document.cookie = 'LastClickCookie=' + tvc_value + ';domain=' + domain + ';path=/';
# }
# });
# }
# }
# }
# }
#
# window.addEventListener("load", function (event) {
# createLastClickCookie();
# });
#
# window.addEventListener("click", function (event) {
# createLastClickCookie();
# tvc_links = document.querySelectorAll('a,button');
# });
#   </script>
#   <header class="header">
#    <div class="cmp-experiencefragment cmp-experiencefragment--header" id="experiencefragment-83228c552b">
#     <!-- SDI include (path: /content/experience-fragments/bajajfinserv/web/in/en/header/master/_jcr_content.content.sharedcontent.html, resourceType: bajajfinserv-web/components/structure/xfpage) -->
#     <div class="cmp-container" id="container-a2f1138e7d">
#      <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
#       <div class="globalHeader tabs aem-GridColumn aem-GridColumn--default--12">
#        <div data-placeholder-text="false">
#         <div class="global-r-header">
#          <div class="horizontal-loader">
#          </div>
#          <div class="r-header r-header--search-expand-view" data-cmp-type="react" data-component="GlobalHeader" data-component-data='{"collapsibleSearch":"false","headerBackground":"true","item0":{"feedbackIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/give-feedback-v4?scl\u003d1\u0026fmt\u003dpng-alpha","logoutConfirmationMessage":"Are You Sure You want to Log Out ?","menuLabel":"Menu","ctaButtonUrlYes":"#","logoutSuccessMessage":"You Have successfully logged out","imageAltText":"My Account","cardImage":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/my-account-v4?scl\u003d1\u0026fmt\u003dpng-alpha","bgColor":"rgba(255,0,255,0.84)","mainNewTab":"false","cardMainSubTitle":"Make loan payments, drawdown funds, explore personalised offers, earn rewards and more","ctaButtonNo":"No","cardMainTitle":"My Account","cardMainUrl":"/myaccountlogin?Source\u003dHome","copyRight":"Â© Bajaj Finance Ltd. 1987-2023. Â© Bajaj Finserv Ltd. 2007-2023. All rights reserved.","rateUsLabel":"Share your experience and help us serve you better","rateUsTitle":"Give feedback","showHideMenu":"true","logoutDelay":"3","logoutLabel":"Logout","medalliaFormID":"3579","ctaButtonYes":"Yes"},"item1":{"headerMyAccountLoggedInUrl":"/myaccountlogin?Source\u003dHome","headerLogoAltText":"Bajaj Finserv","enableIpp":"false","headerLogoUrl":"/","headerMobileLogo":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/bfl-logo-mobile-v6?scl\u003d1\u0026fmt\u003dpng-alpha","headerDesktopLogo":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/bfl-logo-desktop-v6?scl\u003d1\u0026fmt\u003dpng-alpha","showHideMenu":"true"},"item2":{},"item3":{"searchPlaceholderText":"Search bajajfinserv.in","suggestedSearchTitle":"Suggested Searches","searchType":"searchbar","recentMaxHistoryCount":"20","recentSearchTitle":"Recent Searches","popularSearchTitle":"Popular Searches","searchResultUrl":"/search"},"item4":{"noNotificationMsg":"No Notification Message","alertMsg":"Alert Message","showHideMenu":"true"},"item5":{"iconTextColor":"rgba(255,0,0,1.00)","logoutConfirmationMessage":"Are you sure you want to sign out?","ctaButtonUrlYes":"#","logoutSuccessMessage":"You have successfully signed out.","enableIpp":"false","profileText":"My Account","viewProfileLink":"/myaccountlogin?Source\u003dProfile","viewProfileText":"View Profile","loginCtaUrl":"/myaccountlogin?Source\u003dLogin","ctaButtonNo":"No","loginCtaButton":"Sign-in","iconBackgroundColor":"rgba(0,255,255,1.00)","showHideMenu":"true","logoutDelay":"2","logOutCta":"Sign Out","showNudgeInDesktop":"false","ctaButtonYes":"Yes"},"item6":{"langIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/preferred-language-1?scl\u003d1\u0026fmt\u003dpng-alpha","languageTitle":"Preferred language","languageCorporateVariation":"false","showHideMenu":"true","languageSubTitle":"Select the language of your choice"},"item7":{"cardSubTitle":"Become our partner in a few simple steps","ourPortalTitleText":"Partners","enableIpp":"false","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/partner-v1?scl\u003d1\u0026fmt\u003dpng-alpha","nudgeColor":"rgba(255,0,0,1.00)","showHideMenu":"true"},"item8":{"enableIpp":"false","cartTitle":"Cart","ctaLink":"/webform/mycart"},"item9":{"redirectionLink":"/insta-emi-card","emiCardTitle":"EMI Card","showHideMenu":"true","openInNewTab":"false"},"componentType":"default"}'>
#           <div class="container-fluid">
#            <div class="r-header__top">
#             <div class="r-header__top__left">
#              <div>
#               <div class="header-hamburger" data-cmp-type="react" data-component="HeaderHamburger" data-component-data='{"cardImage":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/my-account-v4?scl=1&amp;fmt=png-alpha","imageAltText":"My Account","feedbackIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/give-feedback-v4?scl=1&amp;fmt=png-alpha","cardMainSubTitle":"Make loan payments, drawdown funds, explore personalised offers, earn rewards and more","mainMenu":{"item0":{"subMenu":{"item0":{"subTitle":"Bajaj Finserv Limited","subURL":"/corporate-bajaj-finserv","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item2":{"subTitle":"Bajaj Allianz General Insurance","subURL":"https://www.bajajallianz.com/about-us.html?utm_source=BF_Corp&amp;utm_medium=top_navigation","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item1":{"subTitle":"Bajaj Finance Limited","subURL":"/corporate-bajaj-finance","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item8":{"subTitle":"Bajaj Finserv Asset Management Limited","subURL":"https://www.bajajamc.com/","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item7":{"subTitle":"Bajaj Finserv Health Limited","subURL":"https://www.bajajfinservhealth.in","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item4":{"subTitle":"Bajaj Finserv Direct Limited","subURL":"https://www.bajajfinservmarkets.in/","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item3":{"subTitle":"Bajaj Allianz Life Insurance","subURL":"https://www.bajajallianzlife.com/about-us.html?utm_source=BF_Corp&amp;utm_medium=top_navigation","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item6":{"subTitle":"Bajaj Financial Securities Limited","subURL":"https://www.bajajfinservsecurities.in/","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item5":{"subTitle":"Bajaj Housing Finance Limited","subURL":"https://www.bajajhousingfinance.in/","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"}},"cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/our-companies-v4?scl=1&amp;fmt=png-alpha","merchantOne":"false","cardSubTitle":"Learn more about our companies","menuNewTab":"false","cardTitle":"Our companies"},"item2":{"subMenu":{"item0":{"subTitle":"Clear your overdue EMIs","signInViaMobileLinkNewTab":"false","payUsingLanLinkText":"LOAN ACCOUNT NUMBER","popUpSubTitle":"Click on any one of the methods to proceed","signInViaMobileLink":"/myaccountlogin?Source=Overdue","payUsingLanLink":"/myaccountpayments/overduepay/payvialan","isRedirectPopUp":"true","popUpTitle":"Clear your overdue EMIs","signInViaMobileLinkText":"OUR CUSTOMER PORTAL","payUsingLanLinkNewTab":"false"},"item2":{"subTitle":"Pay your other bills","subURL":"https://bfl.onelink.me/857331112/WEBSITE1","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item1":{"subTitle":"Manage SuperCard bill","subURL":"https://pgi.billdesk.com/pgidsk/pgmerc/rtncard/index.jsp","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"},"item3":{"subTitle":"Make Online Payment","subURL":"/myaccountlogin?Source=Payments","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsingLanLinkNewTab":"false"}},"cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/pay-your-emi-v4?scl=1&amp;fmt=png-alpha","merchantOne":"false","cardSubTitle":"Check your overdue amount and pay online","menuNewTab":"false","cardTitle":"Pay your dues"},"item1":{"subMenu":{"item0":{"subTitle":"Reach Us","subURL":"/reach-us","signInViaMobileLinkNewTab":"false","isRedirectPopUp":"false","payUsi ...
#               </div>
#              </div>
#              <div>
#               <div data-cmp-type="react" data-component="HeaderLogo" data-component-data='{"headerMyAccountLoggedInUrl":"/myaccountlogin?Source=Home",":type":"bajajfinserv-web/components/content/headerlogo","headerLogoUrl":"/","headerMobileLogo":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/bfl-logo-mobile-v6?scl=1&amp;fmt=png-alpha","showHideMenu":"true","vanityPath":"/en","headerLogoAltText":"Bajaj Finserv","headerDesktopLogo":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/bfl-logo-desktop-v6?scl=1&amp;fmt=png-alpha","enableIpp":"false"}'>
#               </div>
#              </div>
#             </div>
#             <div class="r-header__top__middle">
#              <div class="r-header__search-wrapper" data-cmp-type="react" data-component="InsightSearchModal" data-component-data='{"searchPlaceholderText":"Search bajajfinserv.in","suggestedSearchTitle":"Suggested Searches","searchType":"searchbar","recentMaxHistoryCount":"20","recentSearchTitle":"Recent Searches","popularSearchTitle":"Popular Searches","searchResultUrl":"/search","popularSearch":{"item0":{"popularSearchText":"Sign in to my account"},"item1":{"popularSearchText":"Personal Loan"},"item2":{"popularSearchText":"Insta EMI Card"},"item3":{"popularSearchText":"Fixed Deposit"},"item4":{"popularSearchText":"Systematic Deposit Plan"},"item5":{"popularSearchText":"Raise a request"}},"item_1641276514798":{"slideBy":"1","cq:panelTitle":"list","enableIpp":"false","headingText":"Popular Products and Services","layoutType":"product","colourType":"black","textIsRich":["true","true","true","true","true","true","true","true","true","true","true","true","true","true","true","true","true","true"],"componentType":"authored","iconDetails":{"item0":{"iconAltText":"Access Your Account","newTab":"true","iconText":"Access Your Account","listingIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/access-your-account-v4?scl\u003d1\u0026fmt\u003dpng-alpha","iconUrl":"https://customer-login.bajajfinserv.in/Customer"},"item1":{"iconAltText":"Bajaj Mall","newTab":"true","iconText":"Bajaj Mall","listingIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/emi-store-v4?scl\u003d1\u0026fmt\u003dpng-alpha","iconUrl":"https://www.bajajmall.in/emi-store?utm_source\u003dbfl_website\u0026utm_medium\u003dreferral\u0026utm_campaign\u003dmkt_insite_search_popular_products\u0026utm_content\u003dpopular_products"},"item2":{"iconAltText":"Raise a Request","newTab":"true","iconText":"Raise a Request","listingIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/raise-a-request-v4?scl\u003d1\u0026fmt\u003dpng-alpha","iconUrl":"https://customer-login.bajajfinserv.in/Customer?Source\u003dRaiseRequest"},"item3":{"iconAltText":"Credit Card","iconText":"Credit Card","listingIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/credit-card-v4?scl\u003d1\u0026fmt\u003dpng-alpha","iconUrl":"/apply-for-credit-card-online"},"item4":{"iconAltText":"View Your Loan Details","newTab":"true","iconText":"View Your Loan Details","listingIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/view-your-loan-details-v4?scl\u003d1\u0026fmt\u003dpng-alpha","iconUrl":"https://customer-login.bajajfinserv.in/Customer?Source\u003dLOAN_DETAILS"},"item5":{"iconAltText":"Health EMI Network Card","iconText":"Health EMI Network Card","listingIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/health-emi-network-card-v4?scl\u003d1\u0026fmt\u003dpng-alpha","iconUrl":"/emi-network-health-emi-card-apply-online"},"item6":{"iconAltText":"Update Contact Details","newTab":"true","iconText":"Update Contact Details","listingIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/update-contact-details-v4?scl\u003d1\u0026fmt\u003dpng-alpha","iconUrl":"https://customer-login.bajajfinserv.in/Customer?Source\u003dUpdate_Details"},"item7":{"iconAltText":"Wallet Care","iconText":"Wallet Care","listingIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/wallet-care-v4?scl\u003d1\u0026fmt\u003dpng-alpha","iconUrl":"/wallet-protect-card-protection-insurance-plan"},"item8":{"iconAltText":"Loan for Doctors","iconText":"Loan for Doctors","listingIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/loan-for-doctors-v4?scl\u003d1\u0026fmt\u003dpng-alpha","iconUrl":"/personal-loan-for-doctors"}}},":type":"bajajfinserv-web/components/content/insitesearch"}'>
#              </div>
#             </div>
#             <div class="r-header__top__right">
#              <ul class="r-header__quick-cta-list list-unstyled mb-0">
#               <li>
#                <div data-cmp-type="react" data-component="HeaderEmiCard" data-component-data='{":type":"bajajfinserv-web/components/content/emicard","showHideMenu":"true","redirectionLink":"/insta-emi-card","emiCardTitle":"EMI Card","openInNewTab":"false"}'>
#                </div>
#               </li>
#               <li>
#                <div data-cmp-type="react" data-component="HeaderNotification" data-component-data='{"noNotificationMsg":"No Notification Message","showHideMenu":"true","alertMsg":"Alert Message","notifications":{"item0":{"openNewTab":"true","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/bajaj-mall-v1-1?scl=1&amp;fmt=png-alpha","showDelete":"No","ctaButtons":{"item0":{"ctaUrl":"https://www.bajajmall.in/emi-store?utm_source=bfl_xsell&amp;utm_medium=xsell_alertmsg&amp;utm_campaign=alertmsg_xsell","openNewTab":"true","ctaText":"SHOP ONLINE"},"item1":{"ctaUrl":"/bajaj-mall-store-locator","openNewTab":"false","ctaText":"LOCATE A STORE"}},"cardSubTitle":"Get the latest ACs, air coolers, refrigerators, lifestyle products and more","cardUrl":"https://www.bajajmall.in/emi-store?utm_source=bfl_xsell&amp;utm_medium=xsell_alertmsg&amp;utm_campaign=alertmsg_xsell","cardTitle":"Shop on No Cost EMIs"},"item2":{"openNewTab":"false","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/get-the-supercard-v4?scl=1&amp;fmt=png-alpha","showDelete":"No","ctaButtons":{"item0":{"ctaUrl":"/credit-card","openNewTab":"false","ctaText":"CHECK NOW"}},"cardSubTitle":"Get the power of 4 cards in 1 with our SuperCard","cardUrl":"/apply-for-credit-card-online?utm_source=bfl_xsell&amp;utm_medium=xsell_alertmsg&amp;utm_campaign=alertmsg_xsell","cardTitle":"Get the SuperCard"},"item1":{"openNewTab":"false","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/insta-emi-card-v4?scl=1&amp;fmt=png-alpha","showDelete":"No","ctaButtons":{"item0":{"ctaUrl":"/insta-emi-card","openNewTab":"false","ctaText":"GET IT NOW"}},"cardSubTitle":"Check your pre-approved offer and get your card in three easy steps","cardUrl":"/insta-emi-network-card-apply-online?utm_source=bfl_xsell&amp;utm_medium=xsell_alertmsg&amp;utm_campaign=alertmsg_xsell","cardTitle":"Insta EMI Card"},"item8":{"openNewTab":"false","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/cibil-5?scl=1&amp;fmt=png-alpha","showDelete":"No","ctaButtons":{"item0":{"ctaUrl":"/check-free-cibil-score?utm_source=bfl_xsell&amp;utm_medium=xsell_alertmsg&amp;utm_campaign=alertmsg_xsell","openNewTab":"false","ctaText":"CHECK SCORE"}},"cardSubTitle":"Stay updated with your latest score and personalised Credit Health Report","cardUrl":"/check-free-cibil-score?utm_source=bfl_xsell&amp;utm_medium=xsell_alertmsg&amp;utm_campaign=alertmsg_xsell","cardTitle":"Check CIBIL Score for free"},"item7":{"openNewTab":"false","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/wallet-care-v4-1?scl=1&amp;fmt=png-alpha","showDelete":"No","ctaButtons":{"item0":{"ctaUrl":"/insurance/wallet-care","openNewTab":"false","ctaText":"KNOW MORE"},"item1":{"ctaUrl":"/marketplace/pocketInsurance/?product=WalletCare&amp;product_code=WPCP&amp;utm_source=organic&amp;utm_medium=bfl","openNewTab":"false","ctaText":"BUY NOW"}},"cardSubTitle":"Safeguard your credit and debit cards and get one year ZEE5 subscription for free.","cardUrl":"/marketplace/pocketInsurance/?product=WalletCare&amp;product_code=WPCP&amp;utm_source=organic&amp;utm_medium=bfl","cardTitle":"Wallet Care at just Rs. 699"},"item4":{"openNewTab":"false","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/personal-loan-v1-4?scl=1&amp;fmt=png-alpha","showDelete":"No","ctaButtons":{"item0":{"ctaUrl":"/personal-loan","openNewTab":"false","ctaText":"KNOW MORE"},"item1":{"ctaUrl":"/personal-loan","openNewTab":"false","ctaText":"APPLY"}},"cardSubTitle":"Get funds up to Rs. 40 lakh with minimal documentation","cardUrl":"/personal-loan","cardTitle":"Personal Loan"},"item3":{"openNewTab":"false","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/fixed-deposit-v4?scl=1&amp;fmt=png-alpha","showDelete":"No","ctaButtons":{"item0":{"ctaUrl":"/investments/fixed-deposit","openNewTab":"false","ctaText":"OPEN FD"}},"cardSubTitle":"Earn up to 8.60% p.a. with our fixed deposit","cardUrl":"/fixed-de ...
#                </div>
#               </li>
#               <li>
#                <div data-cmp-type="react" data-component="HeaderCart" data-component-data='{":type":"bajajfinserv-web/components/content/headercart","cartTitle":"Cart","ctaLink":"/webform/mycart","enableIpp":"false"}'>
#                </div>
#               </li>
#               <li>
#                <div data-cmp-type="react" data-component="HeaderMyAccount" data-component-data='{"profileText":"My Account","loginCtaUrl":"/myaccountlogin?Source=Login","viewProfileLink":"/myaccountlogin?Source=Profile","showHideMenu":"true","logoutSuccessMessage":"You have successfully signed out.","iconTextColor":"rgba(255,0,0,1.00)","logoutDelay":"2","ctaButtonYes":"Yes","viewProfileText":"View Profile","dropdownlist":{"item0":{"ctaText":"View Loan Details","ctaLink":"/myaccountlogin?Source=Loan"},"item2":{"ctaText":"Update Contact Details","ctaLink":"/myaccountlogin?Source=Profile"},"item1":{"ctaText":"Raise a Request","ctaLink":"/myaccountlogin?Source=RAR"},"item3":{"ctaText":"View Payments Report","ctaLink":"/myaccountlogin?Source=Document"}},"loginCtaButton":"Sign-in",":type":"bajajfinserv-web/components/content/myaccount","logoutConfirmationMessage":"Are you sure you want to sign out?","showNudgeInDesktop":"false","ctaButtonUrlYes":"#","ctaButtonNo":"No","iconBackgroundColor":"rgba(0,255,255,1.00)","logOutCta":"Sign Out","enableIpp":"false"}'>
#                </div>
#               </li>
#               <li>
#               </li>
#               <li>
#                <div data-cmp-type="react" data-component="HeaderOurPortal" data-component-data='{"nudgeColor":"rgba(255,0,0,1.00)",":type":"bajajfinserv-web/components/content/ourportals","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/partner-v1?scl=1&amp;fmt=png-alpha","showHideMenu":"true","cardSubTitle":"Become our partner in a few simple steps","ourPortalTitleText":"Partners","iconCardDetails":{"item0":{"cardtitleText":"Debt Management Partner","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/debt-management-service-v5?scl=1&amp;fmt=png-alpha","iconUrl":"/enrollment-for-collection-partner"},"item2":{"cardtitleText":"Fixed Deposit Partner","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/fixed-desposit-v5?scl=1&amp;fmt=png-alpha","iconNewTab":"true","iconUrl":"https://business-loan.bajajfinance.com/sitepages/IFAEmpanelment.aspx"},"item1":{"cardtitleText":"EMI Network Partner","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/emi-network-partners-v5?scl=1&amp;fmt=png-alpha","iconUrl":"/become-our-partner"},"item4":{"cardtitleText":"Partners Sign In","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/partner-one?scl=1&amp;fmt=png-alpha","iconNewTab":"true","iconUrl":"https://partners.bajajfinserv.in/"},"item3":{"cardtitleText":"Become a Merchant","cardIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/merchant-qr-image-2883183?scl=1&amp;fmt=png-alpha","iconNewTab":"true","iconUrl":"https://business.bajajfinserv.in/"}},"enableIpp":"false"}'>
#                </div>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="topnavigation aem-GridColumn aem-GridColumn--default--12">
#        <div data-cmp-type="react" data-component="SecondaryBottomNavigation" data-component-data='{"signInNudgeDisappearTime":"5000","signInNudgeIcon":"https://cms-assets.bajajfinserv.in/is/image/bajajfinance/vector-signin?scl\u003d1\u0026fmt\u003dpng-alpha","signInNudgeText":"Sign-in","signInNudgeIconAltText":"Sign-in","signInNudgeBackgroundColour":"#FFF2EA","noSearchResultsText":"No search result found","mopinionFormID":"b154adf738b124d6eb68c9018a0748698217f728","searchProductsText":"Search our products","signInNudgeTextColour":"#002953","signInNudgeBorderColour":"#FF6700","signInNudgeAppearTime":"2000","productOfferingText":"Our Product Offering","showSignInNudgeInMobile":"true","navigation":{"item0":{"xfLink":"/content/experience-fragments/bajajfinserv/web/in/en/header/secondary-navigation/loans/loan/master","secondarynavigation":{"secondaryNavigation":{"item0":{"signInViaMobileLinkNewTab":"false","submenuNewTab":"false","firstctatype":"cta-button","firstopeninnewtab":"false","subMenuLabel":"All Loans","subMenuLink":"/loans","secondopeninnewtab":"false","secondtctatype":"cta-button","payUsingLanLinkNewTab":"false"},"item1":{"signInViaMobileLinkNewTab":"false","submenuNewTab":"false","secondcta":"Check Offer","xfLink":"/content/experience-fragments/bajajfinserv/web/in/en/header/ternary-navigation/loan/loan/personal-loan","ternarynavigation":{"viewButtonVariant":"true","twoColumnLayout":"false","headerMenu":{"item0":{"columnPlacement":"firstColumn","ctaList":{"item0":{"titleUrl":"/personal-loan","title":"Overview"},"item1":{"titleUrl":"/flexi-loans","title":"Flexi Personal Loan"},"item2":{"titleUrl":"/personal-loan-features","title":"Features and Benefits"},"item3":{"titleUrl":"/personal-loan-eligibility-and-documents","title":"Eligibility"},"item4":{"titleUrl":"/interest-calculator","title":"Calculator"},"item5":{"titleUrl":"/personal-loan-fees-and-charges","title":"Fees and Charges"},"item6":{"titleUrl":"/how-to-apply-for-personal-loan","title":"How to Apply"},"item7":{"titleUrl":"/personal-loan-faq-questions","title":"FAQs"},"item8":{"titleUrl":"/service-guides/manage-your-loans-in-my-account","title":"Manage your Loans"},"item9":{"titleUrl":"/service-guides/manage-your-flexi-loans-in-my-account","title":"Manage your Flexi Loans"},"item10":{"titleUrl":"/personal-loan-contact-details","title":"Contact Us"}}},"item1":{"subMenuHeaderText":"Loans for your Goals","columnPlacement":"firstColumn","ctaList":{"item0":{"titleUrl":"/personal-loan-for-wedding","title":"Loan for Wedding","coloredcta":"true"},"item1":{"titleUrl":"/personal-loan-for-higher-education","title":"Loan for Higher Education","coloredcta":"true"},"item2":{"titleUrl":"/personal-loan-for-home-expenses","title":"Loan for Home Renovation","coloredcta":"true"},"item3":{"titleUrl":"/personal-loan-for-medical-emergency","title":"Loan for Medical Emergency","coloredcta":"true"}}}}},"firstctatype":"cta-button","firstctaurl":"/personal-loan","firstopeninnewtab":"false","firstcta":"Apply Online","secondctaurl":"/personal-loan","subMenuLabel":"Personal Loan","secondopeninnewtab":"false","secondtctatype":"cta-button","payUsingLanLinkNewTab":"false"},"item2":{"signInViaMobileLinkNewTab":"false","submenuNewTab":"false","secondcta":"Pre-approved Offer","xfLink":"/content/experience-fragments/bajajfinserv/web/in/en/header/ternary-navigation/loan/loan/insta-personal-loan","ternarynavigation":{"viewButtonVariant":"true","twoColumnLayout":"false","headerMenu":{"item0":{"columnPlacement":"firstColumn","ctaList":{"item0":{"titleUrl":"/insta-personal-loan","title":"Overview"},"item1":{"titleUrl":"/insta-personal-loan-features","title":"Features"},"item2":{"titleUrl":"/insta-personal-loan-eligibility-and-documents","title":"Eligibility"},"item3":{"titleUrl":"/insta-personal-loan-emi-calculator","title":"Calculator"},"item4":{"titleUrl":"/insta-personal-loan-fees-and-charges","title":"Fees and Charges"},"item5":{"titleUrl":"/how-to-generate-offer-for-insta-personal-loan","title":"How  ...
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div data-cmp-type="react" data-component="UserLoginSSO">
#   </div>
#   <div class="home-horizontalnavigation-wrapper horizontalnavigation-component-loading">
#    <div data-cmp-type="react" data-component="HomeHorizontalNavigation" data-component-data='{":type":"/apps/bajajfinserv-web/components/content/homepagehorizontalnavigation"}'>
#    </div>
#   </div>
#   <section class="container-fluid main-content hp-main-content">
#    <div class="root container responsivegrid">
#     <div class="cmp-container" id="container-083587108f">
#      <div class="container responsivegrid">
#       <div class="cmp-container" id="container-052ae4a5be">
#        <div class="responsivegrid hp-main-content__left-column">
#         <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
#          <div class="maintenance404 aem-GridColumn aem-GridColumn--default--12">
#           <section class="container-fluid">
#            <div class="maintenance404" data-component="Maintenance404">
#             <div class="maintenance404__left">
#              <div class="maintenance404__img-box">
#               <img alt="error 404" class="w-100" loading="lazy" src="https://cms-assets.bajajfinserv.in/is/image/bajajfinance/404?scl=1&amp;fmt=png-alpha"/>
#              </div>
#             </div>
#             <div class="maintenance404__right">
#              <h1 class="maintenance404__title">
#               Page not found
#              </h1>
#              <p>
#               We couldnât find what you were looking for...
#              </p>
#              <p>
#               <strong>
#                <p>
#                 <strong>
#                  To go to our home page
#                  <a>
#                   click here
#                  </a>
#                  , or enter your query in the search
#               bar above
#                 </strong>
#                </p>
#               </strong>
#              </p>
#             </div>
#            </div>
#           </section>
#          </div>
#          <div class="experiencefragment aem-GridColumn aem-GridColumn--default--12">
#          </div>
#         </div>
#        </div>
#        <div class="responsivegrid hp-main-content__right-column">
#         <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
#         </div>
#        </div>
#        <div class="experiencefragment">
#         <div class="cmp-experiencefragment cmp-experiencefragment--sso-login" id="experiencefragment-a216fad14b">
#          <!-- SDI include (path: /content/experience-fragments/bajajfinserv/web/in/en/sso-login/master/_jcr_content.content.sharedcontent.html, resourceType: bajajfinserv-web/components/structure/xfpage) -->
#          <div class="cmp-container" id="container-e77564346c">
#           <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
#            <div class="login componentseo aem-GridColumn aem-GridColumn--default--12">
#             <div data-cmp-type="react" data-component="OfferLoginModal" data-component-data='{"subHeadingText":"Please enter your 10-digit mobile number to get started","salariedbuttonText":"Salaried","formSubHeadingText":"Please share a few details to start your application","pincodeLabelText":"PIN Code","submitBtnText":"Get OTP","firstNameEmptyText":"Please enter your first name as per your PAN Card","mobileNumberLabelText":"Mobile number","lastNameLabelText":"Last Name","salaryInvalidText":"Please enter monthly salary amount","proceedBtnText":"Proceed","firstNameSupportText":"Enter your first name as it appears on your PAN Card","formHeadingText":"Get started","employmentTypeSupportText":"Please select your type of employment","pincodeEmptyText":"Please enter your 6-digit current residential PIN Code","fullNameSupportText":"Enter your name","nonsalariedbuttonValue":"Self Employed","minimumSalaryAmount":"0","formMobileNumberLabelText":"Mobile Number","mobileNumberEmptyText":"Please enter your mobile number","fullNameEmptyText":"Please enter your name","nonsalariedbuttonText":"Self-employed","salaryLabelText":"Monthly Income","formSubmitBtnText":"GET OTP","mobileNumberInvalidText":"Please enter valid mobile number","currencySymbol":"Rs.","pincodeInvalidText":"Please enter a valid 6-digit current residential PIN Code","fullNameLabelText":"Full Name","offersRedirectURL":"#","lastNameInvalidText":"Please enter your last name as per your PAN Card","firstNameInvalidText":"Please enter your first name as per your PAN Card","errorMessages":[{"message":"Maximum incorrect OTP attempts reached. Please try again after 3 minutes","statusCode":"otp_93"},{"message":"Something went wrong at our end, please try again after some time","statusCode":"login_99"},{"message":"OTP disabled due to maximum incorrect OTP attempts. Please try again after 30 minutes","statusCode":"otp_94"},{"message":"Something went wrong at our end, please try again after some time","statusCode":"otp_99"},{"message":"Too many login attempts, please try again after some time","statusCode":"login_91"},{"message":"Please send the required details for attachment","statusCode":"rar_91"},{"message":"Please request OTP and try again","statusCode":"otp_91"},{"message":"Something went wrong, please try again","statusCode":"login_92"},{"message":"Something went wrong, please try again","statusCode":"otp_97"},{"message":"OTP already validated, please generate OTP again","statusCode":"otp_92"},{"message":"Invalid OTP, please try again","statusCode":"otp_98"},{"message":"OTP Sent","statusCode":"login_90"},{"message":"OTP validated successfully","statusCode":"otp_90"}],"headingText":"SIGN IN","fullNameInvalidText":"Enter valid name","employmentLabelText":"Employment type","firstNameLabelText":"First Name","lastNameEmptyText":"Please enter your last name as per your PAN Card","salariedbuttonValue":"Salaried","hideFirstName":"true","formMobileNumberSupportText":"Enter your 10-digit mobile number","pincodeSupportText":"Enter your 6-digit residential PIN Code","salaryEmptyText":"Please enter monthly salary amount","enableIpp":"false","lastNameSupportText":"Enter your last name as it appears on your PAN Card"}'>
#             </div>
#            </div>
#            <div class="otp componentseo aem-GridColumn aem-GridColumn--default--12">
# ...
#                   Privacy Policy
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/phishing" target="_self">
#                   Phishing
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/disclaimer-page" target="_self">
#                   Disclaimer
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/forms-centre" target="_self">
#                   Forms Centre
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/all-fees-and-charges" target="_self">
#                   Fees &amp; Charges
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/investment-about-us-fair-practices-code" target="_self">
#                   Fair Practices Code
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="https://cms-assets.bajajfinserv.in/is/content/bajajfinance/interest-rate-policypdf?scl=1&amp;fmt=pdf" loading="lazy" target="_blank">
#                   Interest Rate Policy
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/disclosures-page" target="_self">
#                   Disclosures
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="https://cms-assets.bajajfinserv.in/is/content/bajajfinance/caution-notice-25-jan-2021-convertedpdf?scl=1&amp;fmt=pdf" target="_blank">
#                   Cautionary Notice
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="https://cms-assets.bajajfinserv.in/is/content/bajajfinance/whistle-blower-policy-v3pdf?scl=1&amp;fmt=pdf" loading="lazy" target="_blank">
#                   Whistle Blower Policy
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/confidential-feedback" target="_self">
#                   Confidential Feedback
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="https://cms-assets.bajajfinserv.in/is/content/bajajfinance/framework-2.0-for-covid19-related-stressdocxpdf?scl=1&amp;fmt=pdf" target="_blank">
#                   Resolution Plan 2.0
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/terms-and-conditions" target="_self">
#                   Terms &amp; Conditions
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="https://cms-assets.bajajfinserv.in/is/content/bajajfinance/faqs-2021pdf?scl=1&amp;fmt=pdf" target="_blank">
#                   Resolution Plan 2.0 FAQs
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/finance-corporate-ombudsman" target="_self">
#                   Ombudsman Scheme
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="https://cms-assets.bajajfinserv.in/is/content/bajajfinance/customer-awareness-regarding-classification-of-loan-account-as-sma-and-npapdf?scl=1&amp;fmt=pdf" loading="lazy" target="_blank">
#                   SMA/NPA Account Classification
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="/terms-of-use" target="_self">
#                   Terms of Use
#                  </a>
#                 </li>
#                 <li>
#                  <a class="footer_navigation_link" href="https://sachet.rbi.org.in/" target="_blank">
#                   Sachet
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="cmp-footer__tabpanel" id="footer-5ef09c6e94-item-bc9500484c-footer">
#          <div class="footerType1">
#           <div class="cmp_footer">
#            <div class="accordion">
#             <div class="accordion__row footer__row">
#              <div class="footer__row-inner">
#               <div class="accordion__header-wrapper">
#                <h3 class="accordion__toggle footer__block-title">
#                 Reach Us
#                </h3>
#               </div>
#               <div class="accordion__body">
#                <div class="footer__body-two-col">
#                 <ul class="footer__links footer__links--two-col">
#                  <li>
#                   <a class="footer_navigation_link" href="/reach-us" target="_self">
#                    Contact us
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_navigation_link" href="/myaccountlogin?Source=RAR" target="_self">
#                    Raise A Request
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_navigation_link" href="/contact-us-faq-queries" target="_self">
#                    Frequently Asked Questions
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_navigation_link" href="/myaccountlogin?Source=Payments" target="_self">
#                    Make Online Payment
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_navigation_link" href="/branch-locator" target="_self">
#                    Branch Locator
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_navigation_link" href="/bajaj-finserv-partners" target="_self">
#                    Our Partners
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_navigation_link" href="https://business-loan.bajajfinance.com/B2B_CustomLogin.aspx" target="_self">
#                    Galaxy - Partner portal
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_navigation_link" href="https://business.bajajfinserv.in/" target="_blank">
#                    Bajaj Finserv for Business
#                   </a>
#                  </li>
#                 </ul>
#                 <ul class="footer__links footer__links--social-share">
#                  <li>
#                   <a class="footer_share_icon facebook" href="https://www.facebook.com/bajajfinserv" target="_self" title="Facebook">
#                    <i class="bf-icon-facebook">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_share_icon linkedin" href="https://www.linkedin.com/company/bajaj-finserv-lending/mycompany/" target="_self" title="LinkedIn">
#                    <i class="bf-icon-linkedin">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_share_icon twitter" href="https://twitter.com/Bajaj_Finserv" target="_self" title="Twitter">
#                    <i class="bf-icon-twitter">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="footer_share_icon youtube" href="https://www.youtube.com/c/bajajfinserv" target="_self" title="YouTube">
#                    <i class="bf-icon-youtube">
#                    </i>
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="footer__row footer__row--bb-none">
#          <div class="footer__row-inner">
#           <div class="footer__last-row">
#            <div class="footer__last-row__left">
#             <div class="footer__col">
#              <div class="footer__col-box">
#               <h3 class="footer__block-title">
#                Corporate Office
#               </h3>
#               <p>
#                6th Floor Bajaj Finserv Corporate Office, Off Pune-Ahmednagar Road, Viman Nagar, Pune - 411014
#               </p>
#              </div>
#             </div>
#             <div class="footer__col">
#              <div class="footer__col-box">
#               <h3 class="footer__block-title">
#                Bajaj Finance Limited Regd. Office
#               </h3>
#               <p>
#                Akurdi, Pune - 411035
#                <br/>
#                Ph No.: 020 7157-6403
#                <br/>
#                Email ID:
#                <a href="mailto:investor.service@bajajfinserv.in" target="_self">
#                 investor.service@bajajfinserv.in
#                </a>
#                <br/>
#                <br/>
#               </p>
#              </div>
#              <div class="footer__col-box">
#               <h3 class="footer__block-title">
#                Corporate Identity Number (CIN)
#               </h3>
#               <p>
#                L65910MH1987PLC042961
#                <br/>
#               </p>
#              </div>
#              <div class="footer__col-box">
#               <h3 class="footer__block-title">
#                IRDAI Corporate Agency Registration Number
#               </h3>
#               <p>
#                CA0101
#                <br/>
#                (Valid till 31-Mar-2025)
#               </p>
#              </div>
#              <div class="footer__col-box">
#               <h3 class="footer__block-title">
#                URN - WEB/BFL/22-23/3/V1
#               </h3>
#              </div>
#             </div>
#             <div class="footer__col">
#              <div class="footer__col-box">
#               <h3 class="footer__block-title">
#                Bajaj Finserv Limited Regd. Office
#               </h3>
#               <p>
#                Bajaj Auto Limited Complex Mumbai - Pune Road,
#                <br/>
#                Pune - 411035 MH (IN)
#                <br/>
#                Ph No.: 020 7157-6064
#                <br/>
#                Email ID:
#                <a href="mailto:investors@bajajfinserv.in">
#                 investors@bajajfinserv.in
#                </a>
#               </p>
#              </div>
#              <div class="footer__col-box">
#               <h3 class="footer__block-title">
#                Corporate Identity Number (CIN)
#               </h3>
#               <p>
#                L65923PN2007PLC130075
#               </p>
#              </div>
#             </div>
#            </div>
#            <div class="footer__last-row__right">
#             <div class="footer__col">
#              <h3 class="footer__block-title">
#               Our Companies
#              </h3>
#              <ul class="footer__links">
#               <li>
#                <a class="footer_navigation_link" href="/corporate-bajaj-finserv" target="_self">
#                 Bajaj Finserv Ltd.
#                </a>
#               </li>
#               <li>
#                <a class="footer_navigation_link" href="/corporate-bajaj-finance" target="_self">
#                 Bajaj Finance Ltd.
#                </a>
#               </li>
#               <li>
#                <a class="footer_navigation_link" href="https://www.bajajallianz.com/general-insurance.html" target="_self">
#                 Bajaj Allianz General Insurance
#                </a>
#               </li>
#               <li>
#                <a class="footer_navigation_link" href="https://www.bajajallianzlife.com" target="_self">
#                 Bajaj Allianz Life Insurance
#                </a>
#               </li>
#               <li>
#                <a class="footer_navigation_link" href="https://www.bajajfinservmarkets.in" target="_self">
#                 Bajaj Finserv Markets
#                </a>
#               </li>
#               <li>
#                <a class="footer_navigation_link" href="https://www.bajajhousingfinance.in" target="_self">
#                 Bajaj Housing Finance Ltd.
#                </a>
#               </li>
#               <li>
#                <a class="footer_navigation_link" href="https://www.bajajfinservsecurities.in/" target="_self">
#                 Bajaj Financial Securities Ltd.
#                </a>
#               </li>
#               <li>
#                <a class="footer_navigation_link" href="https://www.bajajfinservhealth.in/" target="_self">
#                 Bajaj Finserv Health Ltd.
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="footer__col">
#              <div class="footer__app-links-wrapper">
#               <div class="footer__app-links-lbl">
#                Download the Bajaj Finserv App
#               </div>
#               <ul class="footer__app-links">
#                <li>
#                 <a class="footer_download_app" href="https://bfl.onelink.me/857331112/4n" target="_self" title="Android">
#                  <i class="bf-icon-android">
#                  </i>
#                 </a>
#                </li>
#                <li>
#                 <a class="footer_download_app" href="https://apps.apple.com/in/app/id505454145" target="_self" title="iOS">
#                  <i class="bf-icon-apple">
#                  </i>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="footer__copyright">
#          Â© Bajaj Finserv 2007-2023. All rights reserved.
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="/etc.clientlibs/bajajfinserv-web/clientlibs/clientlib-site-onload.min.eb75ffcaac1f0657ed4324131f6e44ad.js">
#   </script>
#   <script src="/etc.clientlibs/bajajfinserv-web/clientlibs/clientlib-site.min.add96d2f0ada93ac77a2c59f5db46717.js">
#   </script>
#   <script src="/etc.clientlibs/clientlibs/granite/jquery.min.cee8557e8779d371fe722bbcdd3b3eb7.js">
#   </script>
#   <script src="/etc.clientlibs/clientlibs/granite/utils.min.4a192b590a2c2926fb000264370c0588.js">
#   </script>
#   <script src="/etc.clientlibs/clientlibs/granite/jquery/granite.min.543d214c88dfa6f4a3233b630c82d875.js">
#   </script>
#   <script src="/etc.clientlibs/core/wcm/components/commons/site/clientlibs/container.min.425fc66dd77250d96ac69dd554a92778.js">
#   </script>
#   <script src="/etc.clientlibs/bajajfinserv-web/clientlibs/clientlib-base.min.5610dcf706882905ac99c271acab7509.js">
#   </script>
#   <script type="text/javascript">
#    if ('serviceWorker' in navigator) {navigator.serviceWorker.register('/service-worker.js', {scope: '/'}) .then(function (reg) { }).catch(function (error) {console.debug('Registration failed with ' + error);});}
# var clevertap = {event: [],profile: [],region: 'in1',account: [],onUserLogin: [],notifications: [],privacy: []};
# clevertap.account.push({"id": "W86-ZK8-K66Z"});clevertap.privacy.push({optOut: false});clevertap.privacy.push({useIP: true});
# (function () {var wzrk = document.createElement('script');wzrk.type = 'text/javascript';wzrk.async = true;wzrk.src = ('https:' == document.location.protocol ? 'https://d2r1yp2w7bby2u.cloudfront.net' :'http://static.clevertap.com') + '/js/clevertap.min.js';var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(wzrk, s);})();
# function getCookie(cname) {var name = cname + "=";var ca = document.cookie.split(';');for (var i = 0; i < ca.length; i++) {var c = ca[i];while (c.charAt(0) == ' ') {c = c.substring(1);}
# if (c.indexOf(name) == 0) {return c.substring(name.length, c.length);}}return "";}var varAuthType;try {var a = getCookie("authType");if (a == "I" || a == "A") {varAuthType = "Identified";}else {varAuthType = "UnIdentified";}} catch (err) {varAuthType = "NA";}
# clevertap.event.push("page_view", {"page_url": document.URL,"authType": varAuthType,});
#   </script>
#  </body>
# </html>

# %%
# Store all links and redirects in a list
all_links = []

# %%
# Extract links from the initial page
links = [get_valid_url(link.get('href'), base_url) for link in soup.find_all('a') if link.get('href')]
all_links.extend(links)

# %%
# Iterate over page URLs
for url1 in page_urls:
    if not url1.startswith('http'):
        print(f"Invalid URL: {url1}. Skipping...")
        continue

    response = requests.get(url1)
    if response.status_code == 200:
        page_soup = bs(response.text, 'html.parser')

        # Extract links from each page
        links = [get_valid_url(link.get('href'), base_url) for link in page_soup.find_all('a') if link.get('href')]
        all_links.extend(links)
    else:
        print(f"Failed to fetch URL: {url1}. Status code: {response.status_code}")
# Out:
# Failed to fetch URL: https://cms-assets.bajajfinserv.in/is/content/bajajfinance/whistle-blower-policy-v3pdf?scl=1&fmt=pdf. Status code: 404
# Failed to fetch URL: https://www.linkedin.com/company/bajaj-finserv-lending/mycompany/. Status code: 999
# Failed to fetch URL: https://twitter.com/Bajaj_Finserv. Status code: 400
# Failed to fetch URL: https://bajajfinserv.in/mailto:investor.service@bajajfinserv.in. Status code: 404
# Failed to fetch URL: https://bajajfinserv.in/mailto:investors@bajajfinserv.in. Status code: 404

# %%
# Filter links with only the base URL and without "javascript:void(0)" and "mailto"
filtered_links = [link for link in all_links if link.startswith(base_url) and "javascript:void(0)" not in link and "mailto" not in link]

# %%
# Save filtered links to a JSON file
json_filename = 'filtered_links.json'

# Remove duplicates by converting the list to a set and then back to a list
filtered_links = list(set(filtered_links))

with open(json_filename, 'w') as json_file:
    json.dump(filtered_links, json_file)

print(f"Filtered Links (with only the base URL) saved to {json_filename}.")
# Out:
# Filtered Links (with only the base URL) saved to filtered_links.json.
